# %%
# Decoder (back to original labels)
decoded_labels = label_encoder.inverse_transform(labels)
decoded_labels

# %% [markdown]
# ### Simple CNN

# %%
# Shuffle data and train/test/split
train_images, test_images, train_labels, test_labels = train_test_split(images, labels, test_size = 0.2, shuffle = True, random_state = 42, stratify = labels)

# %%
cnn_model.fit(train_images, train_labels, epochs = 10)
# Out:
# Epoch 1/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9792 - loss: 0.0978
# Epoch 2/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9851 - loss: 0.0665
# Epoch 3/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9909 - loss: 0.0586
# Epoch 4/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 1.0000 - loss: 0.0362
# Epoch 5/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 1.0000 - loss: 0.0418
# Epoch 6/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0257
# Epoch 7/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 1.0000 - loss: 0.0222
# Epoch 8/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 1.0000 - loss: 0.0148
# Epoch 9/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0154
# Epoch 10/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0105

# %%
predictions = cnn_model.predict(test_images)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step

# %%
predicted_labels = np.argmax(predictions, axis = 1)

# %%
print('Predicted values:')
print(predicted_labels[:10])

print('True values:')
print(test_labels[:10])
# Out:
# Predicted values:
# [ 4  0  1  1  2  0  6  2 10  0]
# True values:
# [ 4  0  1  1  2  0  6  2 10  0]

# %%
# Evaluation metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score

accuracy = accuracy_score(test_labels, predicted_labels)
precision = precision_score(test_labels, predicted_labels, average = 'weighted')
recall = recall_score(test_labels, predicted_labels, average = 'weighted')

print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
# Out:
# Accuracy: 0.9838709677419355
# Precision: 0.9865591397849462
# Recall: 0.9838709677419355
